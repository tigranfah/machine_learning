# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def poly(x, degree):
    return [x**i for i in range(1, degree)]

# %%
X = np.linspace(0, 10, 10)
test_x = [poly(x, 6) for x in X]

# %%
plt.plot(test_x);
