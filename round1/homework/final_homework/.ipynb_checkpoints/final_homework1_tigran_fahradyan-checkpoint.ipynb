# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from cvxopt import solvers
from cvxopt import matrix

# %%
def generate_data(sample_size, c0_p, c1_p, random_state=124):

    rand = np.random.RandomState(random_state)
    
    c0 = rand.normal(*c0_p, (sample_size, 2))
    c1 = rand.normal(*c1_p, (sample_size, 2))
    c0_l = np.full(sample_size, -1)
    c1_l = np.ones(sample_size)

    # data
    x = np.concatenate((c0, c1))
    t = np.concatenate((c0_l, c1_l))
    
    return x, t

def shuffle_data(X, T, random_state=125):
    
    rand = np.random.RandomState(random_state)
    
    # shuffle data
    shuffle_mask = np.arange(len(X))
    rand.shuffle(shuffle_mask)

    return X[shuffle_mask], T[shuffle_mask]

X, T = shuffle_data(*generate_data(250, (2, 2), (11, 2)))

# %%
plt.scatter(X[:, 0], X[:, 1], c=T);

# %%
from sklearn.model_selection import train_test_split

def train_test_validation(X, T, test_size, random_state=14):
    X_train_, x_travel_, X_test_, t_travel_ = train_test_split(X, T, 
                                                           test_size=test_size, 
                                                           random_state=random_state)
    t_train_, v_train_, t_test_, v_test_ = train_test_split(x_travel, 
                                                        t_travel, 
                                                        test_size=0.5, 
                                                        random_state=random_state)
    
    return X_train_, v_train_, t_train_, X_test_, v_test_, t_test_

# %%
# split data
X_train, v_train, t_train, X_test, v_test, t_test = train_test_validation(X, T, test_size=0.3)

# %%
# define kernel
def kernel(x, x_):
    return x.T.dot(x_)

# %% [markdown]
# ## Model

# %%
class SVM:
    
    def __init__(self, kernel, c):
        self.kernel = kernel
        self.c = c
    
    def train(self, X, T, minimal_support_vector_multiplier=0.05):
        # find multipliers - a
        a = self.__find_multipliers(X, T, minimal_support_vector_multiplier)
        
        indices = a > minimal_support_vector_multiplier
        
        self.a = a[indices]
        self.supp_vec = X[indices]
        self.supp_vec_t = T[indices]
        
        self.n_supp_vec = np.sum(indices == True)

        self.b = self.__find_b()
        
        return self
        
    def predict(self, x, include_b=True):
        b = self.b if include_b else 0
        return np.sign(sum([
            self.a[i] * self.supp_vec_t[i] * self.kernel(self.supp_vec[i], x) + b
            for i in range(self.n_supp_vec)
        ]))
    
    def predict_all(self, t_train):
        return np.array([self.predict(x) for x in t_train])
    
    def score(self, t_train, t_test):
        return np.sum(self.predict_all(t_train) == t_test) / len(t_train)
    
    def __find_b(self):
        return sum([
            self.supp_vec_t[n] - self.predict(self.supp_vec[n], include_b=False)
            for n in range(self.n_supp_vec)
        ]) / self.n_supp_vec
    
    def __find_multipliers(self, X, T, minimal_support_vector_multiplier):
        # prepare the parameters for solition
        length = len(X)
        q = matrix(np.full(length, -1, dtype=np.float64))
        P = matrix(np.array([
            t1*t2*self.kernel(x1, x2) for x1, t1 in zip(X, T) for x2, t2 in zip(X, T)]
        ).reshape(-1, length))
        A = matrix(T.reshape(1, length))
        G = matrix(np.concatenate((np.eye(length) * -1, np.eye(length))))
        h = matrix(np.hstack((np.zeros(length), np.full(length, self.c))))
        b = matrix(0.0)
        
        sol = solvers.qp(P=P, q=q, G=G, h=h, A=A, b=b)
        return np.ravel(sol['x'])

# %%
# add this decorator to every function 
# in which you want cvxopt logg to be off
def off_cvxopt_log(func):
    
    def wrapper(*args, **kwargs):
        solvers.options['show_progress'] = False
        f = func(*args, **kwargs)
        solvers.options['show_progress'] = True
        return f
    
    return wrapper

# %% [markdown]
# Find best **hyperparameters** for SMV.

# %%
@off_cvxopt_log
def find_best_model(X, T, C, kernel, folds=5):
    
    fold_size = len(X) // folds
    models_and_scores = []
    
    # cross validation
    for fold in range(folds):
        mask = np.ones(len(X), dtype=bool)
        mask[fold * fold_size: (fold + 1) * fold_size] = False
        
        x_train, t_train, x_test, t_test = X[mask], X[~mask], T[mask], T[~mask]
        
        models = [
            SVM(kernel, c).train(x_train, x_test, 0.001)
            for c in C
        ]
        
        models_and_scores.extend([(model, model.score(t_train, t_test)) for model in models])
    
    index = np.argmax(np.array(models_and_scores)[:, 1])
    return models_and_scores[index]

# %%
# test train
svm = SVM(kernel, c=0.05)
svm.train(X_train, X_test)
# Out:
# /home/tigran/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in long_scalars

# %%
# possible C values
C = [num for num in np.arange(0.01, 2, 0.05)]
C[:5]
# Out:
# [0.01, 0.060000000000000005, 0.11, 0.16000000000000003, 0.21000000000000002]

# %%
best_model, best_score = find_best_model(X_train, X_test, C=C, kernel=kernel)

# %%
best_model, best_score, best_model.c
# Out:
# (<__main__.SVM at 0x7ff3701dd710>, 1.0, 0.11)

# %%
best_model.b
# Out:
# -1.0

# %%
# support vectors for two different classes
plt.scatter(best_model.supp_vec[:, 0], best_model.supp_vec[:, 1], c=best_model.supp_vec_t);

# %%
# test on test data
best_model.score(t_train, t_test)
# Out:
# 0.9866666666666667

# %% [markdown]
# Now generate different data

# %%
def distance_2d(x, x_):
    d1, d2 = abs(x[:, 0] - x_[:, 0]), abs(x[:, 1] - x_[:, 1])
    return np.sqrt(d1**2 + d2**2)

X1, _ = generate_data(300, (3, 1), (3, 3), random_state=126)

radius = 6

dists = distance_2d(X1, np.full(X1.shape, 3))

indices = np.argwhere(dists > 2)
index_mask = np.ones(len(X1), dtype=bool)
index_mask[indices] = False

c0, c1 = X1[index_mask], X1[~index_mask]
c0_l, c1_l = np.ones(np.sum(index_mask)), np.full(np.sum(~index_mask), 0)

# %%
x_ = np.concatenate((c1, c2))
t_ = np.concatenate((c1_l, c2_l))
X_, T_ = shuffle_data(x_, t_)

# %% [markdown]
# **Data** layout

# %%
plt.scatter(X_[:, 0], X_[:, 1], c=T_);

# %%
# split data
X_train, v_train, t_train, X_test, v_test, t_test = train_test_validation(X_, T_, test_size=0.4)

# %%
# guassion kernel
def guassion_kernel(x, x_, sigma=0.1):
    # formula taken from web
    return np.exp(-np.sqrt(np.linalg.norm(x - x_) ** 2 / (2 * sigma ** 2)))

# %%
#                                                      same C values
best_model, best_score = find_best_model(X_train, X_test, C=C, kernel=guassion_kernel)
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-880-c392205f3df3> in <module>
#       1 #                                                      same C values
# ----> 2 best_model, best_score = find_best_model(X_train, X_test, C=C, kernel=guassion_kernel)
#
# <ipython-input-872-a241598df938> in wrapper(*args, **kwargs)
#       5     def wrapper(*args, **kwargs):
#       6         solvers.options['show_progress'] = False
# ----> 7         f = func(*args, **kwargs)
#       8         solvers.options['show_progress'] = True
#       9         return f
#
# <ipython-input-873-21116844283a> in find_best_model(X, T, C, kernel, folds)
#      14         models = [
#      15             SVM(kernel, c).train(x_train, x_test, 0.001)
# ---> 16             for c in C
#      17         ]
#      18
#
# <ipython-input-873-21116844283a> in <listcomp>(.0)
#      14         models = [
#      15             SVM(kernel, c).train(x_train, x_test, 0.001)
# ---> 16             for c in C
#      17         ]
#      18
#
# <ipython-input-876-bd3bcc635532> in train(self, X, T, minimal_support_vector_multiplier)
#       7     def train(self, X, T, minimal_support_vector_multiplier=0.05):
#       8         # find multipliers - a
# ----> 9         a = self.__find_multipliers(X, T, minimal_support_vector_multiplier)
#      10
#      11         indices = a > minimal_support_vector_multiplier
#
# <ipython-input-876-bd3bcc635532> in __find_multipliers(self, X, T, minimal_support_vector_multiplier)
#      52         b = matrix(0.0)
#      53
# ---> 54         sol = solvers.qp(P=P, q=q, G=G, h=h, A=A, b=b)
#      55         return np.ravel(sol['x'])
#
# ~/anaconda3/lib/python3.7/site-packages/cvxopt/coneprog.py in qp(P, q, G, h, A, b, solver, kktsolver, initvals, **kwargs)
#    4483             'residual as dual infeasibility certificate': dinfres}
#    4484
# -> 4485     return coneqp(P, q, G, h, None, A,  b, initvals, kktsolver = kktsolver, options = options)
#
# ~/anaconda3/lib/python3.7/site-packages/cvxopt/coneprog.py in coneqp(P, q, G, h, dims, A, b, initvals, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#    1912         if A.typecode != 'd' or A.size[1] != q.size[0]:
#    1913             raise TypeError("'A' must be a 'd' matrix with %d columns" \
# -> 1914                 %q.size[0])
#    1915         def fA(x, y, trans = 'N', alpha = 1.0, beta = 0.0):
#    1916             base.gemv(A, x, y, trans = trans, alpha = alpha, beta = beta)
#
# TypeError: 'A' must be a 'd' matrix with 304 columns
