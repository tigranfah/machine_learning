# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from importlib import reload

import clustering

clustering = reload(clustering)

from clustering import k_means, MeasureFunctions

# %%
rand = np.random.RandomState(123)

# info about data
length = 250
cluster_count = 3
ndim = 2

cluster_X = []
cluster_y = []

for i, (x_off, y_off) in zip(range(cluster_count), [(0, 0), (15, 15), (25, 0)]):
    cluster_X.append(rand.normal((x_off, y_off), 3, (length, ndim)))
    cluster = np.zeros((length, cluster_count))
    cluster[:, i] = 1
    cluster_y.append(cluster)
    
X = np.concatenate(cluster_X)
y = np.concatenate(cluster_y)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y);

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.4, 
                                                    random_state=123)

# %%
k_means_alg = k_means(cluster_count, MeasureFunctions.distances_measure)

# %%
k_means_alg.train(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-956-4ea958c331a6> in <module>
# ----> 1 k_means_alg.train(X_train)
#
# ~/Desktop/python3/machine_learning_course/round2/homework/clustering_homework/clustering.py in train(self, data, sample_nks, sample_nk_limits)
#      37                 self.k.append(self.nk.copy())
#      38                 self.__expectation(data)
# ---> 39                 self.__minimization(data)
#      40
#      41         def predict(self, test_data):
#
# ~/Desktop/python3/machine_learning_course/round2/homework/clustering_homework/clustering.py in __minimization(self, data)
#      57 						for column in binary_columns]
#      58                 for i in range(len(self.nk)):
# ---> 59                         self.nk[i] = data[k_cluster_xs[i]].mean(axis=1)
#      60                         print(self.nk[i])
#
# ...

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.scatter(k_means_alg.nk[:, 0], k_means_alg.nk[:, 1], c='black', marker='+')
plt.show()

# %%
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.scatter(k_means_alg.k[0][:, 0], k_means_alg.k[0][:, 1], c='black', marker='+')
plt.show()

# %%
a = np.array([[1, 2], [3, 4], [5, 6]])
# a.mean(axis=1)
a.mean()
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])
